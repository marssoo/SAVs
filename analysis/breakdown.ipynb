# %%
import pandas as pd

# %%
df = pd.read_csv('result_csvs/all_val.csv').drop(columns=['Unnamed: 0'])

# %%
df.sort_values('eurosat_acc', ascending=False).head(5)
# Out:
#            model  num_heads   score  hp1  hp2  pets_acc  pets_std  MHalu_acc  \
# 614  llava_ov_7b         40      l2  NaN  NaN  0.984958  0.121720   0.819383
# 12   llava_ov_7b         25   polar  NaN  NaN  0.986763  0.114288   0.834802
# 4    llava_ov_7b         25    base  NaN  NaN  0.986763  0.114288   0.834802
# 615  llava_ov_7b         50      l2  NaN  NaN  0.984958  0.121720   0.832599
# 300  llava_ov_7b         25  artanh  1.5  1.5  0.986763  0.114288   0.823789
#
#      MHalu_std  eurosat_acc  ...  natural_ret_raw_std  natural_ret_q_acc  \
# 614   0.384700     0.842985  ...             0.356865           0.704641
# 12    0.371359     0.840448  ...             0.349465           0.719409
# 4     0.371359     0.840448  ...             0.349465           0.719409
# 615   0.373333     0.839701  ...             0.357897           0.702532
# 300   0.381000     0.838507  ...             0.349465           0.719409
#
#      natural_ret_q_std  natural_ret_i_acc  natural_ret_i_std  \
# ...

# %%
df[df['num_heads']==25].sort_values('vlguard_acc', ascending=False).head(10)
# Out:
#           model  num_heads   score   hp1   hp2  pets_acc  pets_std  MHalu_acc  \
# 4   llava_ov_7b         25    base   NaN   NaN  0.986763  0.114288   0.834802
# 12  llava_ov_7b         25   polar   NaN   NaN  0.986763  0.114288   0.834802
# 20  llava_ov_7b         25  artanh  0.30  0.30  0.986763  0.114288   0.823789
# 28  llava_ov_7b         25  artanh  0.30  0.54  0.986763  0.114288   0.823789
# 36  llava_ov_7b         25  artanh  0.30  0.78  0.986763  0.114288   0.823789
# 44  llava_ov_7b         25  artanh  0.30  1.02  0.986763  0.114288   0.823789
# 52  llava_ov_7b         25  artanh  0.30  1.26  0.986763  0.114288   0.823789
# 60  llava_ov_7b         25  artanh  0.30  1.50  0.986763  0.114288   0.823789
# 68  llava_ov_7b         25  artanh  0.54  0.30  0.986763  0.114288   0.823789
# 76  llava_ov_7b         25  artanh  0.54  0.54  0.986763  0.114288   0.823789
#
#     MHalu_std  eurosat_acc  ...  natural_ret_raw_std  natural_ret_q_acc  \
# ...

# %%
acc_columns = df.filter(like='_acc')
df['avg_acc'] = acc_columns.mean(axis=1)

# %%
df[df['num_heads'] == 5].sort_values('avg_acc', ascending=False).head(50)
# Out:
#            model  num_heads   score   hp1   hp2  pets_acc  pets_std  \
# 24   llava_ov_7b          5  artanh  0.30  0.54  0.981348  0.135293
# 16   llava_ov_7b          5  artanh  0.30  0.30  0.981348  0.135293
# 32   llava_ov_7b          5  artanh  0.30  0.78  0.981348  0.135293
# 40   llava_ov_7b          5  artanh  0.30  1.02  0.981348  0.135293
# 56   llava_ov_7b          5  artanh  0.30  1.50  0.981348  0.135293
# 48   llava_ov_7b          5  artanh  0.30  1.26  0.981348  0.135293
# 80   llava_ov_7b          5  artanh  0.54  0.78  0.981348  0.135293
# 88   llava_ov_7b          5  artanh  0.54  1.02  0.981348  0.135293
# 64   llava_ov_7b          5  artanh  0.54  0.30  0.981348  0.135293
# 72   llava_ov_7b          5  artanh  0.54  0.54  0.981348  0.135293
# 96   llava_ov_7b          5  artanh  0.54  1.26  0.981348  0.135293
# 104  llava_ov_7b          5  artanh  0.54  1.50  0.981348  0.135293
# 120  llava_ov_7b          5  artanh  0.78  0.54  0.981348  0.135293
# ...
