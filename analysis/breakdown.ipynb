# %%
import pandas as pd

# %%
df = pd.read_csv('all_val_benchmarks.csv').drop(columns=['Unnamed: 0'])

# %%
df.sort_values('pets_acc', ascending=False).head(10)
# Out:
#         model  num_heads   score  hp1   hp2  pets_acc  pets_std  MHalu_acc  \
# 306  qwenn2vl         15    base  NaN   NaN  0.989771  0.100618   0.823789
# 307  qwenn2vl         20    base  NaN   NaN  0.989771  0.100618   0.825991
# 314  qwenn2vl         15   polar  NaN   NaN  0.989771  0.100618   0.823789
# 315  qwenn2vl         20   polar  NaN   NaN  0.989771  0.100618   0.825991
# 562  qwenn2vl         15  artanh  1.5  0.30  0.989771  0.100618   0.823789
# 563  qwenn2vl         20  artanh  1.5  0.30  0.989771  0.100618   0.821586
# 570  qwenn2vl         15  artanh  1.5  0.54  0.989771  0.100618   0.823789
# 571  qwenn2vl         20  artanh  1.5  0.54  0.989771  0.100618   0.821586
# 322  qwenn2vl         15  artanh  0.3  0.30  0.989771  0.100618   0.823789
# 323  qwenn2vl         20  artanh  0.3  0.30  0.989771  0.100618   0.821586
#
#      MHalu_std  eurosat_acc  ...  natural_ret_raw_acc  natural_ret_raw_std  \
# ...

# %%
df[df['score']=='base'].sort_values('pets_acc', ascending=False).head(10)
# Out:
#            model  num_heads score  hp1  hp2  pets_acc  pets_std  MHalu_acc  \
# 306     qwenn2vl         15  base  NaN  NaN  0.989771  0.100618   0.823789
# 307     qwenn2vl         20  base  NaN  NaN  0.989771  0.100618   0.825991
# 308     qwenn2vl         25  base  NaN  NaN  0.989170  0.103504   0.821586
# 309     qwenn2vl         30  base  NaN  NaN  0.989170  0.103504   0.828194
# 310     qwenn2vl         40  base  NaN  NaN  0.988568  0.106308   0.825991
# 5    llava_ov_7b         30  base  NaN  NaN  0.987365  0.111695   0.825991
# 305     qwenn2vl         10  base  NaN  NaN  0.987365  0.111695   0.817181
# 304     qwenn2vl          5  base  NaN  NaN  0.987365  0.111695   0.819383
# 4    llava_ov_7b         25  base  NaN  NaN  0.986763  0.114288   0.834802
# 311     qwenn2vl         50  base  NaN  NaN  0.986763  0.114288   0.823789
#
#      MHalu_std  eurosat_acc  ...  natural_ret_raw_acc  natural_ret_raw_std  \
# ...
